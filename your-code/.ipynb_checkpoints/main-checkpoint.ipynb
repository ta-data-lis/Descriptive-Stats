# %% [markdown]
# # Understanding Descriptive Statistics
#
# Import the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Challenge 1
# #### 1.- Define a function that simulates rolling a dice 10 times. Save the information in a dataframe.
# **Hint**: you can use the *choices* function from module *random* to help you with the simulation.

# %%
# your code here
def simulate_dice_rolls():
    rolls = pd.DataFrame({'Roll': [random.choice(range(1,7)) for i in range(10)]})
    return rolls

rolls = simulate_dice_rolls()
print(rolls)
# Out:
#    Roll
# 0     4
# 1     2
# 2     3
# 3     5
# 4     4
# 5     1
# 6     1
# 7     4
# 8     1
# 9     3

# %% [markdown]
# #### 2.- Plot the results sorted by value.

# %%
# your code here



rolls = simulate_dice_rolls()
sorted_rolls = rolls.sort_values('Roll')


plt.bar(sorted_rolls.index, sorted_rolls['Roll'])
plt.xticks(sorted_rolls.index, sorted_rolls['Roll'])
plt.xlabel('Roll')
plt.ylabel('Count')
plt.title('Simulated Dice Rolls (Sorted by Value)')
plt.show()

# %% [markdown]
# #### 3.- Calculate the frequency distribution and plot it. What is the relation between this plot and the plot above? Describe it with words.

# %%
# your code here


rolls = simulate_dice_rolls()
freq = rolls['Roll'].value_counts().sort_index()

plt.bar(freq.index, freq.values)
plt.xlabel('Roll')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Simulated Dice Rolls')
plt.show()

# %%
"""
your comments here
 #It's similar to the previous plot of the rolls sorted by value, but instead of showing the individual roll outcomes, it shows the frequency of each value
"""
# Out:
# "\nyour comments here\n #It's similar to the previous plot of the rolls sorted by value, but instead of showing the individual roll outcomes, it shows the frequency of each value\n"

# %% [markdown]
# ## Challenge 2
# Now, using the dice results obtained in *challenge 1*, your are going to define some functions that will help you calculate the mean of your data in two different ways, the median and the four quartiles.
#
# #### 1.- Define a function that computes the mean by summing all the observations and dividing by the total number of observations. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here
def mean(values):
    total = 0
    count = 0
    for value in values:
        total += value
        count += 1
    return total / count

# %% [markdown]
# #### 2.- First, calculate the frequency distribution. Then, calculate the mean using the values of the frequency distribution you've just computed. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here


def simulate_dice_rolls():
    rolls = pd.DataFrame({'Roll': [random.choice(range(1,7)) for i in range(10)]})
    return rolls

rolls = simulate_dice_rolls()
freq = rolls['Roll'].value_counts().sort_index()

total = 0
count = 0
for value, frequency in freq.items():
    total += value * frequency
    count += frequency

mean = total / count
print('Mean:', mean)
# Out:
# Mean: 4.1

# %% [markdown]
# #### 3.- Define a function to calculate the median. You are not allowed to use any methods or functions that directly calculate the median value.
# **Hint**: you might need to define two computation cases depending on the number of observations used to calculate the median.

# %%
# your code here
def median(values):
    values = sorted(values)
    n = len(values)
    if n % 2 == 0:
        
        mid = n // 2
        return (values[mid - 1] + values[mid]) / 2
    else:
        
        return values[n // 2]

# %% [markdown]
# #### 4.- Define a function to calculate the four quartiles. You can use the function you defined above to compute the median but you are not allowed to use any methods or functions that directly calculate the quartiles.

# %%
# your code here
def quartiles(values):
    values = sorted(values)
    n = len(values)
    if n % 2 == 0:
        
        q1 = median(values[:n//2])
        q3 = median(values[n//2:])
    else:
        
        q1 = median(values[:(n-1)//2])
        q3 = median(values[(n+1)//2:])

    q2 = median(values)
    
    return q1, q2, q3

# %% [markdown]
# ## Challenge 3
# Read the csv `roll_the_dice_hundred.csv` from the `data` folder.
# #### 1.- Sort the values and plot them. What do you see?

# %%
# your code here
data = pd.read_csv("C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/roll_the_dice_hundred.csv")
plt.plot(data)

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### 2.- Using the functions you defined in *challenge 2*, calculate the mean value of the hundred dice rolls.

# %%
import numpy as np

def quartiles(values):
    q1 = np.percentile(values, 25)
    q2 = np.percentile(values, 50)
    q3 = np.percentile(values, 75)
    return q1, q2, q3

# %%
data = pd.read_csv("C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/roll_the_dice_hundred.csv")

# Extract the dice rolls into a list
rolls = data["roll"].tolist()

# Calculate the quartiles and mean
q1, q2, q3 = quartiles(rolls)
mean_value = sum(rolls) / len(rolls)

# Print the results
print("First quartile: {:.2f}".format(q1))
print("Second quartile (median): {:.2f}".format(q2))
print("Third quartile: {:.2f}".format(q3))
print("Mean value: {:.2f}".format(mean_value))
# Out:
# First quartile: 24.75
# Second quartile (median): 49.50
# Third quartile: 74.25
# Mean value: 49.50

# %% [markdown]
# #### 3.- Now, calculate the frequency distribution.

# %%
# your code here

data = pd.read_csv('C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/roll_the_dice_hundred.csv')


freq_dist = data['roll'].value_counts()


print(freq_dist)
# Out:
# 0     1
# 63    1
# 73    1
# 72    1
# 71    1
#      ..
# 30    1
# 29    1
# 28    1
# 27    1
# 99    1
# Name: roll, Length: 100, dtype: int64

# %% [markdown]
# #### 4.- Plot the histogram. What do you see (shape, values...) ? How can you connect the mean value to the histogram?

# %%
# your code here

data= pd.read_csv('C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/roll_the_dice_hundred.csv')

# Calculate the frequency distribution
freq_dist = data['roll'].value_counts()

# Plot the histogram
freq_dist.plot(kind='bar', color='red')

# Add labels and title
plt.xlabel('Dice Roll')
plt.ylabel('Frequency')
plt.title('Dice Roll Histogram')
plt.xlabel('Dice Roll', fontsize=12, rotation=0)
freq_dist.plot(kind='bar', color='blue', figsize=(8, 6))
freq_dist.plot(kind='bar', color='blue', align='center')
plt.xticks(rotation=0, fontsize=8)
plt.xticks(range(1, 12), fontsize=10)





plt.show()

# %%
"""
your comments here
"""

# %% [markdown]
# #### 5.- Read the `roll_the_dice_thousand.csv` from the `data` folder. Plot the frequency distribution as you did before. Has anything changed? Why do you think it changed?

# %%
# your code here
data = pd.read_csv("C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/roll_the_dice_thousand.csv")
plt.plot(data)

# %%
def quartiles(values):
    q1 = np.percentile(values, 25)
    q2 = np.percentile(values, 50)
    q3 = np.percentile(values, 75)
    return q1, q2, q3

# %%
data = pd.read_csv("C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/roll_the_dice_thousand.csv")


rolls = data["roll"].tolist()


q1, q2, q3 = quartiles(rolls)
mean_value = sum(rolls) / len(rolls)


print("First quartile: {:.2f}".format(q1))
print("Second quartile (median): {:.2f}".format(q2))
print("Third quartile: {:.2f}".format(q3))
print("Mean value: {:.2f}".format(mean_value))
# Out:
# First quartile: 249.75
# Second quartile (median): 499.50
# Third quartile: 749.25
# Mean value: 499.50

# %%
"""
your comments here
"""

# %% [markdown]
# ## Challenge 4
# In the `data` folder of this repository you will find three different files with the prefix `ages_population`. These files contain information about a poll answered by a thousand people regarding their age. Each file corresponds to the poll answers in different neighbourhoods of Barcelona.
#
# #### 1.- Read the file `ages_population.csv`. Calculate the frequency distribution and plot it as we did during the lesson. Try to guess the range in which the mean and the standard deviation will be by looking at the plot.

# %% [markdown]
# #### 2.- Calculate the exact mean and standard deviation and compare them with your guesses. Do they fall inside the ranges you guessed?

# %%
"""
your comments here
 (ages_population2.csv) has a more even distribution than the first one (ages_population1.csv). In the second dataset, the age groups have more similar frequency counts, while in the first dataset, there are a few age groups that have significantly higher frequency counts than others. 
"""

# %% [markdown]
# #### 3.- Now read the file `ages_population2.csv` . Calculate the frequency distribution and plot it.

# %%
# your code here
data = pd.read_csv("C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/ages_population2.csv")
freq_dist = data['observation'].value_counts()

# sort the frequency distribution by age
freq_dist = freq_dist.sort_index()

# plot the histogram
plt.hist(data['observation'], bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age distribution')
plt.show()

# %% [markdown]
# ####  4.- What do you see? Is there any difference with the frequency distribution in step 1?

# %%
"""
your comments here
"""

# %% [markdown]
# #### 5.- Calculate the mean and standard deviation. Compare the results with the mean and standard deviation in step 2. What do you think?

# %%
# your code here
import csv
import statistics as stats

with open('C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/ages_population2.csv', 'r') as f:
    reader = csv.reader(f)
    data = []
    for row in reader:
        if row[0] != 'observation':
            data.append(float(row[0]))

mean = stats.mean(data)
stdev = stats.stdev(data)

print("Mean: ", mean)
print("Standard deviation: ", stdev)
# Out:
# Mean:  27.155
# Standard deviation:  2.9698139326891835

# %%
"""
your comments here
"""

# %% [markdown]
# ## Challenge 5
# Now is the turn of `ages_population3.csv`.
#
# #### 1.- Read the file `ages_population3.csv`. Calculate the frequency distribution and plot it.

# %%
# your code here
data = pd.read_csv("C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/ages_population3.csv")
freq_dist = data['observation'].value_counts()


freq_dist = freq_dist.sort_index()


plt.hist(data['observation'], bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age distribution')
plt.show()

# %% [markdown]
# #### 2.- Calculate the mean and standard deviation. Compare the results with the plot in step 1. What is happening?

# %%
# your code here


# read the csv file
data = pd.read_csv("C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/ages_population3.csv")

# calculate the mean
mean = data['observation'].mean()

# calculate the standard deviation
std = data['observation'].std()

print("Mean:", mean)
print("Standard deviation:", std)
# Out:
# Mean: 41.989
# Standard deviation: 16.144705959865934

# %%
"""
your comments here
The larger standard deviation in this distribution indicates that the data points are more spread out from the mean, which is due to the longer tail of older ages. Therefore, the differences in the distribution shape and parameters between the two plots are due to the characteristics of the sampled populations in each neighborhood.
"""

# %% [markdown]
# #### 3.- Calculate the four quartiles. Use the results to explain your reasoning for question in step 2. How much of a difference is there between the median and the mean?

# %%
import pandas as pd

df = pd.read_csv('C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/ages_population3.csv')
print(df.columns)
# Out:
# Index(['observation'], dtype='object')

# %%
# your code here

data = pd.read_csv("C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/ages_population3.csv")


q1 = df['observation'].quantile(0.25)
median = df['observation'].median()
q3 = df['observation'].quantile(0.75)


print("Q1:", q1)
print("Median:", median)
print("Q3:", q3)
# Out:
# Q1: 30.0
# Median: 40.0
# Q3: 53.0

# %%
"""
your comments here
The difference between the mean and median values is larger in the age_population2.csv file, which indicates that the distribution is even more skewed in that dataset. This is supported by the frequency distribution plot, where there is a noticeable peak around the age of 70, which indicates that there is a significant portion of the population in that age range.
"""

# %% [markdown]
# #### 4.- Calculate other percentiles that might be useful to give more arguments to your reasoning.

# %%
# your code here


data = np.loadtxt('C:/Users/sanaz/OneDrive/Desktop/lab-list/week4/day3/lab/Descriptive-Stats/data/ages_population3.csv', skiprows=1)


p10 = np.percentile(data, 10)
p90 = np.percentile(data, 90)

print("10th percentile: ", p10)
print("90th percentile: ", p90)
# Out:
# 10th percentile:  22.0
# 90th percentile:  67.0

# %%
"""
your comments here
"""

# %% [markdown]
# ## Bonus challenge
# Compare the information about the three neighbourhoods. Prepare a report about the three of them. Remember to find out which are their similarities and their differences backing your arguments in basic statistics.

# %%
# your code here

# %%
"""
your comments here
Overall, we can see that the age distribution in the three neighborhoods is similar, but with some variations in the mean, median, and standard deviation. The dataset ages_population1 has the smallest spread of data, with a small range and a low standard deviation. On the other hand, ages_population3 has the largest spread of data, with a wider range and a higher standard deviation. Ages_population2 is somewhere in between, with a similar range to ages_population1, but a higher standard deviation.
"""
