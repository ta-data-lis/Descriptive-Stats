# %% [markdown]
# # Understanding Descriptive Statistics
#
# Import the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %% [markdown]
# ## Challenge 1
# #### 1.- Define a function that simulates rolling a dice 10 times. Save the information in a dataframe.
# **Hint**: you can use the *choices* function from module *random* to help you with the simulation.

# %%
# your code here
list1 = []
for i in range(10):
    a = random.choice([1,2,3,4,5,6])
    list1.append(a)
    
print(list1)
    
dice = pd.DataFrame(list1)
dice.columns = ["nrs"]
# Out:
# [1, 1, 3, 3, 4, 4, 5, 5, 1, 6]

# %% [markdown]
# #### 2.- Plot the results sorted by value.

# %%
# your code here
dice.sort_values(by="nrs")

sns.distplot(dice.value_counts())
plt.show()
# Out:
# C:\Users\pedro\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### 3.- Calculate the frequency distribution and plot it. What is the relation between this plot and the plot above? Describe it with words.

# %%
# your code here

plt.boxplot(dice)
# shows max, mix, mean and 1st and 3rd qt
plt.show()

# %%
"""
shows us that the mean is lower then the mode so the results display are nagatively sweeked 
"""

# %% [markdown]
# ## Challenge 2
# Now, using the dice results obtained in *challenge 1*, your are going to define some functions that will help you calculate the mean of your data in two different ways, the median and the four quartiles.
#
# #### 1.- Define a function that computes the mean by summing all the observations and dividing by the total number of observations. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here

def mean():
    mean = sum(dice["nrs"])/len(dice["nrs"])
    return mean

mean()
# Out:
# 3.3

# %% [markdown]
# #### 2.- First, calculate the frequency distribution. Then, calculate the mean using the values of the frequency distribution you've just computed. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here
sum(dice.value_counts())/len(dice.value_counts())
# Out:
# 2.0

# %% [markdown]
# #### 3.- Define a function to calculate the median. You are not allowed to use any methods or functions that directly calculate the median value.
# **Hint**: you might need to define two computation cases depending on the number of observations used to calculate the median.

# %%
# your code here

def median():
    print((np.sort(dice)[4]+np.sort(dice)[5])/2)
    
median()

# The median will be 4
# Out:
# [4.]

# %% [markdown]
# #### 4.- Define a function to calculate the four quartiles. You can use the function you defined above to compute the median but you are not allowed to use any methods or functions that directly calculate the quartiles.

# %%
# your code here

def quart():
    q1 = np.quantile(dice, 0.25)
    print("the first quartile is: ",q1)
    q2 = np.quantile(dice, 0.50)
    print("the second quartile is: ",q2)
    q3 = np.quantile(dice, 0.75)
    print("the third quartile is: ",q3)

quart()
# Out:
# the first quartile is:  1.5
# the second quartile is:  3.5
# the third quartile is:  4.75

# %% [markdown]
# ## Challenge 3
# Read the csv `roll_the_dice_hundred.csv` from the `data` folder.
# #### 1.- Sort the values and plot them. What do you see?

# %%
# your code here

roll = pd.read_csv("roll_the_dice_hundred.csv")
roll = roll.sort_values(by="value")
sns.kdeplot(roll['value'], shade=True)

plt.show()

# %%
"""
your comments here
seems to be positively skewed 
"""

# %% [markdown]
# #### 2.- Using the functions you defined in *challenge 2*, calculate the mean value of the hundred dice rolls.

# %%
# your code here
def mean():
    mean = sum(roll["value"])/len(roll["value"])
    return mean

mean()
# Out:
# 3.74

# %% [markdown]
# #### 3.- Now, calculate the frequency distribution.

# %%
# your code here
values = roll["value"].value_counts()
values = pd.DataFrame(values)

values
# Out:
#    value
# 1    175
# 3    175
# 4    168
# 2    167
# 6    166
# 5    149

# %% [markdown]
# #### 4.- Plot the histogram. What do you see (shape, values...) ? How can you connect the mean value to the histogram?

# %%
# your code here
dice1 = pd.DataFrame(roll)

plt.hist(roll["value"], bins=6)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
"""
your comments here
The mean is 3.74, which makes sense since one of the highest columns is for nr 3 with a count of 175.
"""

# %% [markdown]
# #### 5.- Read the `roll_the_dice_thousand.csv` from the `data` folder. Plot the frequency distribution as you did before. Has anything changed? Why do you think it changed?

# %%
# your code here
roll = pd.read_csv("roll_the_dice_thousand.csv")
roll = roll.sort_values(by="value")
sns.kdeplot(roll['value'], shade=True)

plt.show()

# %%
"""
your comments here
yes, there are almost equal spikes on each of the values (1-6), 
while on the previous you could see the some values had higher spikes then other
"""

# %% [markdown]
# ## Challenge 4
# In the `data` folder of this repository you will find three different files with the prefix `ages_population`. These files contain information about a poll answered by a thousand people regarding their age. Each file corresponds to the poll answers in different neighbourhoods of Barcelona.
#
# #### 1.- Read the file `ages_population.csv`. Calculate the frequency distribution and plot it as we did during the lesson. Try to guess the range in which the mean and the standard deviation will be by looking at the plot.

# %%
# your code here
ages = pd.read_csv("ages_population.csv")
sns.kdeplot(ages['observation'], shade=True)

# mean should be around 40
# std deviation around 10
# Out:
# <AxesSubplot:xlabel='observation', ylabel='Density'>

# %% [markdown]
# #### 2.- Calculate the exact mean and standard deviation and compare them with your guesses. Do they fall inside the ranges you guessed?

# %%
# your code here
print(ages.mean())
print(ages.std())
# Out:
# observation    36.56
# dtype: float64
# observation    12.8165
# dtype: float64

# %%
"""
your comments here
yes, there were more of less close to the guesses
"""

# %% [markdown]
# #### 3.- Now read the file `ages_population2.csv` . Calculate the frequency distribution and plot it.

# %%
# your code here
ages2 = pd.read_csv("ages_population2.csv")
sns.kdeplot(ages2['observation'], shade=True)
# Out:
# <AxesSubplot:xlabel='observation', ylabel='Density'>

# %% [markdown]
# ####  4.- What do you see? Is there any difference with the frequency distribution in step 1?

# %%
"""
your comments here
Yes, the shape is very similiar but the mean and mode seem to be lower
"""

# %% [markdown]
# #### 5.- Calculate the mean and standard deviation. Compare the results with the mean and standard deviation in step 2. What do you think?

# %%
# your code here
print(ages2.mean())
print(ages2.std())
# Out:
# observation    27.155
# dtype: float64
# observation    2.969814
# dtype: float64

# %%
"""
your comments here
They are both lower, std deviation is also lower since the data frame seems to contain a more limited array of values
"""

# %% [markdown]
# ## Challenge 5
# Now is the turn of `ages_population3.csv`.
#
# #### 1.- Read the file `ages_population3.csv`. Calculate the frequency distribution and plot it.

# %%
# your code here
ages3 = pd.read_csv("ages_population3.csv")
sns.kdeplot(ages3['observation'], shade=True)
# Out:
# <AxesSubplot:xlabel='observation', ylabel='Density'>

# %% [markdown]
# #### 2.- Calculate the mean and standard deviation. Compare the results with the plot in step 1. What is happening?

# %%
# your code here
print(ages3.mean())
print(ages3.std())
# Out:
# observation    41.989
# dtype: float64
# observation    16.144706
# dtype: float64

# %%
"""
your comments here
The range of the sample data is even bigger so the mean and the standard deviation are both larger then data sets 1 and 2
"""

# %% [markdown]
# #### 3.- Calculate the four quartiles. Use the results to explain your reasoning for question in step 2. How much of a difference is there between the median and the mean?

# %%
# your code here
def quart():
    q1 = np.quantile(ages3, 0.25)
    print("the first quartile is: ",q1)
    q2 = np.quantile(ages3, 0.50)
    print("the second quartile is: ",q2)
    q3 = np.quantile(ages3, 0.75)
    print("the third quartile is: ",q3)

quart()
# Out:
# the first quartile is:  30.0
# the second quartile is:  40.0
# the third quartile is:  53.0

# %%
"""
your comments here
the mean is slightly higher then the median so this means this particullarly dataset is skewed positively 
"""

# %% [markdown]
# #### 4.- Calculate other percentiles that might be useful to give more arguments to your reasoning.

# %%
# your code here
import statistics as st
st.multimode(ages3["observation"])
# Out:
# [32.0]

# %%
"""
your comments here
The mode is lower then both the mean and the median, which confirms the trend line is definetly skewed positively
"""

# %% [markdown]
# ## Bonus challenge
# Compare the information about the three neighbourhoods. Prepare a report about the three of them. Remember to find out which are their similarities and their differences backing your arguments in basic statistics.

# %%
# your code here

# %%
"""
your comments here
"""
